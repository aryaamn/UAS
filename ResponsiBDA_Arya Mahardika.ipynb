# %%
import pandas as pd
data = pd.read_csv('dr_fika.csv', sep=';')
data.head(5)
# Out:
#       screen_name           username              user_id  \
# 0         Dr_Hepp  Tobias Elfsten 🇸🇪            432731949
# 1  kerandomankata   Saya aneh disini  1245991272709382145
# 2         Dr_Hepp  Tobias Elfsten 🇸🇪            432731949
# 3  kerandomankata   Saya aneh disini  1245991272709382145
# 4         konkodi      konkodi_Kenya            468680689
#
#               tweet_id                                   tweet_url  \
# 0  1257569495104794630         /Dr_Hepp/status/1257569495104794630
# 1  1257222799476875264  /kerandomankata/status/1257222799476875264
# 2  1257569495104794630         /Dr_Hepp/status/1257569495104794630
# 3  1257222799476875264  /kerandomankata/status/1257222799476875264
# 4  1258664453513646080         /konkodi/status/1258664453513646080
#
#              timestamp  timestamp_epochs  \
# 0  2020-05-05 07:15:06        1588662906
# 1  2020-05-04 08:17:28        1588580248
# 2  2020-05-05 07:15:06        1588662906
# ...

# %%
data.isnull().sum()
# Out:
# screen_name           0
# username              0
# user_id               0
# tweet_id              0
# tweet_url             0
# timestamp             0
# timestamp_epochs      0
# text                  2
# text_html             0
# links                 0
# hashtags              0
# has_media             0
# img_urls              0
# video_url           489
# likes                 0
# retweets              0
# replies               0
# is_replied            0
# is_reply_to           0
# parent_tweet_id     200
# reply_to_users        0
# dtype: int64

# %%
import pandas as pd
import numpy as np

data_olah = 'dr_fika.csv'
dataset = pd.read_csv(data_olah, sep=';')
data.head(5)
# Out:
#       screen_name           username              user_id  \
# 0         Dr_Hepp  Tobias Elfsten 🇸🇪            432731949
# 1  kerandomankata   Saya aneh disini  1245991272709382145
# 2         Dr_Hepp  Tobias Elfsten 🇸🇪            432731949
# 3  kerandomankata   Saya aneh disini  1245991272709382145
# 4         konkodi      konkodi_Kenya            468680689
#
#               tweet_id                                   tweet_url  \
# 0  1257569495104794630         /Dr_Hepp/status/1257569495104794630
# 1  1257222799476875264  /kerandomankata/status/1257222799476875264
# 2  1257569495104794630         /Dr_Hepp/status/1257569495104794630
# 3  1257222799476875264  /kerandomankata/status/1257222799476875264
# 4  1258664453513646080         /konkodi/status/1258664453513646080
#
#              timestamp  timestamp_epochs  \
# 0  2020-05-05 07:15:06        1588662906
# 1  2020-05-04 08:17:28        1588580248
# 2  2020-05-05 07:15:06        1588662906
# ...

# %%
data.isnull().sum()
# Out:
# screen_name           0
# username              0
# user_id               0
# tweet_id              0
# tweet_url             0
# timestamp             0
# timestamp_epochs      0
# text                  2
# text_html             0
# links                 0
# hashtags              0
# has_media             0
# img_urls              0
# video_url           489
# likes                 0
# retweets              0
# replies               0
# is_replied            0
# is_reply_to           0
# parent_tweet_id     200
# reply_to_users        0
# dtype: int64

# %%
pip install Sastrawi
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install nltk
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install stopwords
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
print('mulai preprocesing data')
print()
print('Case Folding')
case_folding = data.apply(lambda x: x.astype(str).str.lower())
print(case_folding)
# Out:
# mulai preprocesing data
#
# Case Folding
#          screen_name                  username              user_id  \
# 0            dr_hepp         tobias elfsten 🇸🇪            432731949
# 1     kerandomankata          saya aneh disini  1245991272709382145
# 2            dr_hepp         tobias elfsten 🇸🇪            432731949
# 3     kerandomankata          saya aneh disini  1245991272709382145
# 4            konkodi             konkodi_kenya            468680689
# ..               ...                       ...                  ...
# 484     wiantinicici             cici wiantini  1201345684525334528
# 485      azahiduddin                     dieya  1124318704341114880
# 486  ninnatrisnawaty  ninna trisnawaty amrizal   992750905291194370
# 487          hayaqu1      marhaban ya ramadhan   885719005599682566
# 488  adamuhussainiy1               mallamadamu   991812696793284609
#
#                 tweet_id                                    tweet_url  \
# ...

# %%
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
import string
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory

# %%
#Stemming
print('Stemming')
factory = StemmerFactory()
stemmer = factory.create_stemmer()
count = 0
x = 300

while count < x:
#     print(count)
    stem_text = stemmer.stem(case_folding['text'][count])
#     print(stem_text)
    case_folding['text'][count] = stem_text
    count += 1

print(case_folding)
# Out:
# Stemming
#          screen_name                  username              user_id  \
# 0            dr_hepp         tobias elfsten 🇸🇪            432731949
# 1     kerandomankata          saya aneh disini  1245991272709382145
# 2            dr_hepp         tobias elfsten 🇸🇪            432731949
# 3     kerandomankata          saya aneh disini  1245991272709382145
# 4            konkodi             konkodi_kenya            468680689
# ..               ...                       ...                  ...
# 484     wiantinicici             cici wiantini  1201345684525334528
# 485      azahiduddin                     dieya  1124318704341114880
# 486  ninnatrisnawaty  ninna trisnawaty amrizal   992750905291194370
# 487          hayaqu1      marhaban ya ramadhan   885719005599682566
# 488  adamuhussainiy1               mallamadamu   991812696793284609
#
#                 tweet_id                                    tweet_url  \
# ...

# %%
#Tokenize
import nltk
nltk.download('punkt')

from nltk.tokenize import word_tokenize

print("Tokenize")
count = 0
x = 300
while count < x:
    tokens = word_tokenize(stemmer.stem(case_folding['text'][count]))
    case_folding['text'][count] = tokens
    count += 1
print(case_folding)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Adityaaarisky\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Tokenize
#          screen_name                  username              user_id  \
# 0            dr_hepp         tobias elfsten 🇸🇪            432731949
# 1     kerandomankata          saya aneh disini  1245991272709382145
# 2            dr_hepp         tobias elfsten 🇸🇪            432731949
# 3     kerandomankata          saya aneh disini  1245991272709382145
# 4            konkodi             konkodi_kenya            468680689
# ..               ...                       ...                  ...
# 484     wiantinicici             cici wiantini  1201345684525334528
# 485      azahiduddin                     dieya  1124318704341114880
# 486  ninnatrisnawaty  ninna trisnawaty amrizal   992750905291194370
# 487          hayaqu1      marhaban ya ramadhan   885719005599682566
# ...

# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
#Stopwords
print("Stopwords")
count = 0
x = 300
stopword=set(stopwords.words('indonesian'))
removed=[]
while count < x:
    for t in case_folding['text'][count]:
        if t not in stopword:
            removed.append(t)
#         else :
#            case_folding['text'][count].remove(t)
    count += 1
    
print('Stopword Removal')
print("Removed Item = ",removed)
# Out:
# Stopwords
# Stopword Removal
# ...

# %%
import pandas as pd
import seaborn as sns
sns.set()
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('dr_fika.csv', delimiter=';')
# df = sns.load_dataset('brain_size.csv', delimiter=';')
df.head()
# Out:
#       screen_name           username              user_id  \
# 0         Dr_Hepp  Tobias Elfsten 🇸🇪            432731949
# 1  kerandomankata   Saya aneh disini  1245991272709382145
# 2         Dr_Hepp  Tobias Elfsten 🇸🇪            432731949
# 3  kerandomankata   Saya aneh disini  1245991272709382145
# 4         konkodi      konkodi_Kenya            468680689
#
#               tweet_id                                   tweet_url  \
# 0  1257569495104794630         /Dr_Hepp/status/1257569495104794630
# 1  1257222799476875264  /kerandomankata/status/1257222799476875264
# 2  1257569495104794630         /Dr_Hepp/status/1257569495104794630
# 3  1257222799476875264  /kerandomankata/status/1257222799476875264
# 4  1258664453513646080         /konkodi/status/1258664453513646080
#
#              timestamp  timestamp_epochs  \
# 0  2020-05-05 07:15:06        1588662906
# 1  2020-05-04 08:17:28        1588580248
# 2  2020-05-05 07:15:06        1588662906
# ...

# %%
import datetime
import seaborn as sns
sns.set()
import matplotlib.pyplot as plt
# %matplotlib inline
data['timestamp'] = list(map(lambda x: datetime.datetime.strptime(x,'%Y-%m-%d %H:%M:%S').strftime('%Y-%m-%d'), data['timestamp']))
v = sns.lineplot(x='timestamp', y='likes', data=data)

# %%
ay = sns.lineplot(x='likes', y='retweets', data=df)
